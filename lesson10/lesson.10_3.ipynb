# %%
import asyncio
import time

async def download_file_async(file_name):
    """模擬下載檔案（非同步版本）"""
    print(f"開始下載 {file_name}...")
    await asyncio.sleep(2)  # 關鍵差異：使用 await，讓出控制權
    print(f"✅ {file_name} 下載完成")
    return f"{file_name}_data"

# 使用 asyncio：同時下載多個檔案
async def main_async():
    start = time.time()

    # 同時啟動 3 個下載任務
    results = await asyncio.gather(
        download_file_async("檔案A.pdf"),
        download_file_async("檔案B.pdf"),
        download_file_async("檔案C.pdf")
    )

    end = time.time() #結束時間
    print(f"\n總耗時: {end - start:.2f} 秒")

# 執行（在 Jupyter 中直接 await main_async()）
if __name__ == "__main__":
    await main_async()
# Out:
# 開始下載 檔案A.pdf...
# 開始下載 檔案B.pdf...
# 開始下載 檔案C.pdf...
# ✅ 檔案A.pdf 下載完成
# ✅ 檔案B.pdf 下載完成
# ✅ 檔案C.pdf 下載完成
#
# 總耗時: 2.01 秒

# %%
import asyncio
from playwright.async_api import async_playwright, Browser,Page

async def main():
    async with async_playwright() as p:
        #開啟瀏覽器
        browser: Browser = await p.chromium.launch()
        page:Page = await browser.new_page()
        await browser.close()
await main()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 10
#       6         #開啟瀏覽器
#       7         browser: Browser = await p.chromium.launch()
#       8         page:Page = await browser.new_page()
#       9         await browser.close()
# ---> 10 await main()
#      11
#
# Cell In[7], line 5, in main()
#       4 async def main():
# ----> 5     async with async_playwright() as p:
#       6         #開啟瀏覽器
#       7         browser: Browser = await p.chromium.launch()
#       8         page:Page = await browser.new_page()
#
# File ~\Documents\github\20260701\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\Documents\github\20260701\.venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\asyncio\base_events.py:1756, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1754     debug_log = f'execute program {program!r}'
#    1755     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1756 transport = await self._make_subprocess_transport(
#    1757     protocol, popen_args, False, stdin, stdout, stderr,
#    1758     bufsize, **kwargs)
#    1759 if self._debug and debug_log is not None:
#    1760     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\asyncio\base_events.py:528, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     524 async def _make_subprocess_transport(self, protocol, args, shell,
#     525                                      stdin, stdout, stderr, bufsize,
#     526                                      extra=None, **kwargs):
#     527     """Create subprocess transport."""
# --> 528     raise NotImplementedError
#
# NotImplementedError:

# %%
import asyncio
from playwright.async_api import async_playwright,Browser,Page

async def main():
    async with async_playwright() as p:
        # 啟動瀏覽器
        browser:Browser = await p.chromium.launch()
        page:Page = await browser.new_page()
        await browser.close()

await main()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[8], line 11
#       7         browser:Browser = await p.chromium.launch()
#       8         page:Page = await browser.new_page()
#       9         await browser.close()
#      10
# ---> 11 await main()
#      12
#
# Cell In[8], line 5, in main()
#       4 async def main():
# ----> 5     async with async_playwright() as p:
#       6         # 啟動瀏覽器
#       7         browser:Browser = await p.chromium.launch()
#       8         page:Page = await browser.new_page()
#
# File ~\Documents\github\20260701\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\Documents\github\20260701\.venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\asyncio\base_events.py:1756, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1754     debug_log = f'execute program {program!r}'
#    1755     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1756 transport = await self._make_subprocess_transport(
#    1757     protocol, popen_args, False, stdin, stdout, stderr,
#    1758     bufsize, **kwargs)
#    1759 if self._debug and debug_log is not None:
#    1760     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\asyncio\base_events.py:528, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     524 async def _make_subprocess_transport(self, protocol, args, shell,
#     525                                      stdin, stdout, stderr, bufsize,
#     526                                      extra=None, **kwargs):
#     527     """Create subprocess transport."""
# --> 528     raise NotImplementedError
#
# NotImplementedError:

# %%
import os

current_dir = os.path.dirname(os.path.abspath(__file__))
print(current_dir)

# %%
import os

current_dir = os.path.dirname(os.path.abspath(__file__))
print(current_dir)
