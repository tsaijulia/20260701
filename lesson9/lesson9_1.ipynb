# %%
__name__
# Out:
# '__main__'

# %%
if __name__ == "__main__":
    print("我是專案檔的主執行檔")
# Out:
# 我是專案檔的主執行檔

# %%
def mailn():
    pass

if __name__ == "__main__":
    print("我是專案檔的主執行檔")
# Out:
# 我是專案檔的主執行檔

# %%
def main():
    print("我是專案檔的主執行檔") 

if __name__ == "__main__":
    main()
# Out:
# 我是專案檔的主執行檔

# %%
import playwright
playwright.sync_api.sync_playwright
# Out:
# <function playwright.sync_api.sync_playwright() -> playwright.sync_api._context_manager.PlaywrightContextManager>

# %%
import playwright
from playwright import sync_api
sync_api.sync_playwright()

# %%
from playwright.sync_api import sync_playwright

sync_playwright()

# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
file  = open("file1.txt")
print(file)
# Out:
# <_io.TextIOWrapper name='file1.txt' mode='r' encoding='cp950'>

# %%
file  = open("file1.txt")
content = file.read()
file.close()
print(content)

# %%
with open("file1.txt")  as file:
    content = file.read()

    print(content)
